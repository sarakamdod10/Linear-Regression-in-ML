# %% [markdown]
# <a href="https://colab.research.google.com/github/sarakamdod10/Linear-Regression-in-ML/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Import required Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
exp_sal = pd.read_csv('/content/Salary_Data.csv')

# %%
exp_sal
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
exp_sal.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %% [markdown]
# 2. Provide Data

# %%
x = exp_sal['YearsExperience'].values.reshape(-1,1)
print(x)
print(type(x))
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# <class 'numpy.ndarray'>

# %%
y = exp_sal['Salary'].values
print(y)
print(type(y))
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]
# <class 'numpy.ndarray'>

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(x,y,
                                                 test_size = 0.2,
                                                 random_state = 2021)

# %%
# create a class for linearRegression
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 3. Create a model and fit it

# %%
 model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model = LinearRegression().fit(x,y)

# %% [markdown]
# 4. Get results

# %%
r_sq = model.score(x,y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.9569566641435084

# %%
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: 25792.200198668696
# slope: [9449.96232146]

# %%
new_model = LinearRegression().fit(x,y.reshape((-1,1)))
print('intercept:', new_model.intercept_)
print('slope:', new_model.coef_)
# Out:
# intercept: [25792.20019867]
# slope: [[9449.96232146]]

# %% [markdown]
# 5. Predict Response

# %%
y_pred = model.predict(x)
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [ 36187.15875227  38077.15121656  39967.14368085  44692.12484158
#   46582.11730587  53197.09093089  54142.08716303  56032.07962732
#   56032.07962732  60757.06078805  62647.05325234  63592.04948449
#   63592.04948449  64537.04571663  68317.03064522  72097.0155738
#   73987.00803809  75877.00050238  81546.97789525  82491.9741274
#   90051.94398456  92886.932681   100446.90253816 103281.8912346
#  108006.87239533 110841.86109176 115566.84225249 116511.83848464
#  123126.81210966 125016.80457395]

# %%
y_pred = model.intercept_ + model.coef_ * x
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [[ 36187.15875227]
#  [ 38077.15121656]
#  [ 39967.14368085]
#  [ 44692.12484158]
#  [ 46582.11730587]
#  [ 53197.09093089]
#  [ 54142.08716303]
#  [ 56032.07962732]
#  [ 56032.07962732]
#  [ 60757.06078805]
#  [ 62647.05325234]
#  [ 63592.04948449]
#  [ 63592.04948449]
#  [ 64537.04571663]
#  [ 68317.03064522]
#  [ 72097.0155738 ]
#  [ 73987.00803809]
#  [ 75877.00050238]
#  [ 81546.97789525]
#  [ 82491.9741274 ]
#  [ 90051.94398456]
#  [ 92886.932681  ]
#  [100446.90253816]
#  [103281.8912346 ]
#  [108006.87239533]
#  [110841.86109176]
#  [115566.84225249]
#  [116511.83848464]
#  [123126.81210966]
#  [125016.80457395]]

# %%
x_new = np.arange(5).reshape((-1,1))
print(x_new)
# Out:
# [[0]
#  [1]
#  [2]
#  [3]
#  [4]]

# %%
y_new = model.predict(x_new)
print(y_new)
# Out:
# [25792.20019867 35242.16252012 44692.12484158 54142.08716303
#  63592.04948449]

# %%
plt.scatter(x,y,color='darkred')
plt.xlabel('Years_Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(train_x,train_y,color='darkred')
plt.plot(train_x,regressor.predict(train_x),color='blue')
plt.xlabel('Years_Experience')
plt.ylabel('Salary')
plt.show()
